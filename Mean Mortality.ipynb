# %%
import pandas as pd

df_all = pd.read_csv("226786564.csv", skiprows=8, nrows=21, usecols=[0,1])
display(df_all)
# Out:
#                  Age  Total mortality
# 0   total (all ages)           541589
# 1       Aged under 1             2571
# 2        Aged 1 to 4              379
# 3        Aged 5 to 9              270
# 4         Aged 10-14              310
# 5         Aged 15-19              831
# 6         Aged 20-24             1359
# 7         Aged 25-29             1823
# 8         Aged 30-34             2534
# 9         Aged 35-39             3607
# 10        Aged 40-44             5020
# 11        Aged 45-49             8705
# 12        Aged 50-54            12964
# 13        Aged 55-59            18180
# 14        Aged 60-64            24305
# 15        Aged 65-69            35848
# 16        Aged 70-74            54180
# 17        Aged 75-79            65236
# 18        Aged 80-84            86686
# 19        Aged 85-89            99610
# 20  Aged 90 and over           117171

# %%
df_male = pd.read_csv("226786564.csv", skiprows=48, nrows=21, usecols=[0,1])
display(df_male)
# Out:
#                  Age  Total mortality
# 0   total (all ages)           267960
# 1       Aged under 1             1440
# 2        Aged 1 to 4              215
# 3        Aged 5 to 9              137
# 4         Aged 10-14              194
# 5         Aged 15-19              561
# 6         Aged 20-24              981
# 7         Aged 25-29             1242
# 8         Aged 30-34             1658
# 9         Aged 35-39             2260
# 10        Aged 40-44             3185
# 11        Aged 45-49             5251
# 12        Aged 50-54             7870
# 13        Aged 55-59            10755
# 14        Aged 60-64            14355
# 15        Aged 65-69            21232
# 16        Aged 70-74            31296
# 17        Aged 75-79            36041
# 18        Aged 80-84            44735
# 19        Aged 85-89            45290
# 20  Aged 90 and over            39262

# %%
df_female = pd.read_csv("226786564.csv", skiprows=88, nrows=22, usecols=[0,1])
display(df_female)
# Out:
#                  Age  Total mortality
# 0   total (all ages)           273629
# 1       Aged under 1             1131
# 2        Aged 1 to 4              164
# 3        Aged 5 to 9              133
# 4         Aged 10-14              116
# 5         Aged 15-19              270
# 6         Aged 20-24              378
# 7         Aged 25-29              581
# 8         Aged 30-34              876
# 9         Aged 35-39             1347
# 10        Aged 40-44             1835
# 11        Aged 45-49             3454
# 12        Aged 50-54             5094
# 13        Aged 55-59             7425
# 14        Aged 60-64             9950
# 15        Aged 65-69            14616
# 16        Aged 70-74            22884
# 17        Aged 75-79            29195
# 18        Aged 80-84            41951
# 19        Aged 85-89            54320
# 20  Aged 90 and over            77909

# %%
def graph(df):
    display(df)
    df['age_trimmed']=df['Age'].str.slice(start=5)
#     df.drop('Age')
    df.set_index('age_trimmed').plot.bar(rot=0, figsize=[20,10])

    
    

df_all['Male'] = df_male['Total mortality']
df_all['Female'] = df_female['Total mortality']


graph(df_all.drop(0))
# Out:
#                  Age  Total mortality   Male  Female
# 1       Aged under 1             2571   1440    1131
# 2        Aged 1 to 4              379    215     164
# 3        Aged 5 to 9              270    137     133
# 4         Aged 10-14              310    194     116
# 5         Aged 15-19              831    561     270
# 6         Aged 20-24             1359    981     378
# 7         Aged 25-29             1823   1242     581
# 8         Aged 30-34             2534   1658     876
# 9         Aged 35-39             3607   2260    1347
# 10        Aged 40-44             5020   3185    1835
# 11        Aged 45-49             8705   5251    3454
# 12        Aged 50-54            12964   7870    5094
# 13        Aged 55-59            18180  10755    7425
# 14        Aged 60-64            24305  14355    9950
# 15        Aged 65-69            35848  21232   14616
# 16        Aged 70-74            54180  31296   22884
# 17        Aged 75-79            65236  36041   29195
# 18        Aged 80-84            86686  44735   41951
# 19        Aged 85-89            99610  45290   54320
# 20  Aged 90 and over           117171  39262   77909

# %%
graph(df_male.drop(0))
graph(df_female.drop(0))
# Out:
#                  Age  Total mortality
# 1       Aged under 1             1440
# 2        Aged 1 to 4              215
# 3        Aged 5 to 9              137
# 4         Aged 10-14              194
# 5         Aged 15-19              561
# 6         Aged 20-24              981
# 7         Aged 25-29             1242
# 8         Aged 30-34             1658
# 9         Aged 35-39             2260
# 10        Aged 40-44             3185
# 11        Aged 45-49             5251
# 12        Aged 50-54             7870
# 13        Aged 55-59            10755
# 14        Aged 60-64            14355
# 15        Aged 65-69            21232
# 16        Aged 70-74            31296
# 17        Aged 75-79            36041
# 18        Aged 80-84            44735
# 19        Aged 85-89            45290
# 20  Aged 90 and over            39262
#                  Age  Total mortality
# 1       Aged under 1             1131
# 2        Aged 1 to 4              164
# 3        Aged 5 to 9              133
# 4         Aged 10-14              116
# 5         Aged 15-19              270
# 6         Aged 20-24              378
# 7         Aged 25-29              581
# 8         Aged 30-34              876
# 9         Aged 35-39             1347
# 10        Aged 40-44             1835
# 11        Aged 45-49             3454
# 12        Aged 50-54             5094
# 13        Aged 55-59             7425
# 14        Aged 60-64             9950
# 15        Aged 65-69            14616
# 16        Aged 70-74            22884
# 17        Aged 75-79            29195
# 18        Aged 80-84            41951
# 19        Aged 85-89            54320
# 20  Aged 90 and over            77909
